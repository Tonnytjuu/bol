# %%
import pandas as pd
import numpy as np
listpages = pd.read_parquet('data/fct_page_view_nl.parque')
listpages['containerId'] = listpages['eventId'].map(lambda e: e.split('.')[0])
listpages
# Out:
# /Users/patrickjonathan/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/patrickjonathan/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:62: UserWarning: Pandas requires version '1.3.4' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (
#                           _surrogate_key dateAmsterdam  \
# 0       bc6c663d8987017154a859a3d60e00ba    2022-11-06
# 1       67f4edd1c0997a3131e2e0b6fcb08c8d    2022-11-06
# 2       82551fd0570e41e9903b63d74a90d85d    2022-11-06
# 3       d375b023dd4f79ebadd044d6a3055760    2022-11-06
# 4       55dd5a271c225756560d805a83714632    2022-11-06
# ...                                  ...           ...
# 692749  a0e0fee7b53188070c1412e733203c48    2022-10-27
# ...

# %%
# i did this to test whether I can push shit lol
import pandas as pd
import numpy as np

add_points = concatenated_df[(concatenated_df['groupType'] == 'BuyBlock') & (concatenated_df['hasClick'] == True)]
add_points

#take the add points ID and its timestamp and the item
#check in the timestamps after that time if people actually bought the same item, if thats the case return true
#filter all the instances where this is the case
#use this for training
#use the model to predict if this is true and train on the data that I received this way
#use the features and CJ as independent variables and this outcome as dependent variable
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/lq/jbrfmdz51qbcss6qvy3ptnrw0000gn/T/ipykernel_6687/3207094170.py in <module>
#       3 import numpy as np
#       4
# ----> 5 add_points = concatenated_df[(concatenated_df['groupType'] == 'BuyBlock') & (concatenated_df['hasClick'] == True)]
#       6 add_points
#
# NameError: name 'concatenated_df' is not defined
